# %%
import pandas as pd

# %%
dmiher = pd.read_csv("Datta Meghe Institute of Higher Education & Research - Wardha [22 Sep].csv")

# %%
dmiher
# Out:
#                    Student Name                 Student Email  \
# 0                Harsh Muppawar    harshmuppawar011@gmail.com
# 1        Shaikh Kahkasha Faisal   shaikhkahkasha523@gmail.com
# 2    Bhairavi Narendra Rewatkar  bhairavirewatkar00@gmail.com
# 3          Sahil Sunil Warudkar   sahilwarudkar2002@gmail.com
# 4                Aayushi Chonde    ayushichonde2002@gmail.com
# ..                          ...                           ...
# 142               Ketan Wanjari      ketan02wanjari@gmail.com
# 143                Trupti Thute      truptithute087@gmail.com
# 144              Khushi Marbate      khushimarbate0@gmail.com
# 145           Moses Makuei Jiet     mosesmakuei2520@gmail.com
# 146               Mayur Gawande     gawandemayur336@gmail.com
#
#                                            Institution  \
# 0    Datta Meghe Institute of Higher Education & Re...
# 1    Datta Meghe Institute of Higher Education & Re...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13948\268476107.py in ?()
# ----> 1 dmiher.show()
#
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
dmiher.dtypes
# Out:
# Student Name                             object
# Student Email                            object
# Institution                              object
# Enrolment Date & Time                    object
# Enrolment Status                         object
# Google Cloud Skills Boost Profile URL    object
# # of Courses Completed                    int64
# # of Skill Badges Completed               int64
# # of GenAI Game Completed                 int64
# Total Completions of both Pathways       object
# Redemption Status                        object
# dtype: object
